# %%
from IPython.display import Image
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/cj.csv', encoding='cp949')
df.head()
# Out:
#        개방시설명      개방장소명 개방시설유형구분   휴관일 평일운영시작시각 평일운영종료시각 주말운영시작시각 주말운영종료시각  \
# 0     청주유도회관     청주유도회관       기타  연중무휴     5:00    22:00     5:00    22:00
# 1    충북스포츠센터    충북스포츠센터      체육관  연중무휴     5:00    22:00     5:00    22:00
# 2     국제테니스장     국제테니스장     테니스장  연중무휴     5:00    22:00     5:00    22:00
# 3  청주정구장(솔밭)  청주정구장(솔밭)       기타  연중무휴     5:00    22:00     5:00    22:00
# 4      실내수영장      실내수영장       기타  연중무휴     5:00    22:00     5:00    22:00
#
#   유료사용여부  사용기준시간  ...  시설사진정보                               소재지도로명주소  소재지지번주소  \
# 0      Y     NaN  ...     NaN  충청북도 청주시 상당구 1순환로1514번길 70(용정동 241외3)      NaN
# 1      Y     NaN  ...     NaN        충청북도 청주시 서원구 흥덕로 37(사직동808-6외7)      NaN
# 2      Y     NaN  ...     NaN          충청북도 청주시 상당구 호미로242 (금천동 327)      NaN
# 3      Y     NaN  ...     NaN      충청북도 청주시 흥덕구 대신로 157 (송정동산140-61)      NaN
# 4      Y     NaN  ...     NaN      충청북도 청주시 서원구 흥덕로 69 (사직1동 788외 1)      NaN
#
# ...

# %%
df
# Out:
#                 개방시설명         개방장소명 개방시설유형구분         휴관일 평일운영시작시각 평일운영종료시각  \
# 0              청주유도회관        청주유도회관       기타        연중무휴     5:00    22:00
# 1             충북스포츠센터       충북스포츠센터      체육관        연중무휴     5:00    22:00
# 2              국제테니스장        국제테니스장     테니스장        연중무휴     5:00    22:00
# 3           청주정구장(솔밭)     청주정구장(솔밭)       기타        연중무휴     5:00    22:00
# 4               실내수영장         실내수영장       기타        연중무휴     5:00    22:00
# 5   올림픽기념관,     국민생활관  올림픽기념관,국민생활관      체육관        연중무휴     5:00    22:00
# 6           청주롤러스케이트장     청주롤러스케이트장       기타        연중무휴     5:00    22:00
# 7              김수녕양궁장        김수녕양궁장       기타        연중무휴     5:00    22:00
# 8              용정축구공원        용정축구공원      축구장        연중무휴     5:00    22:00
# 9               청주국궁장         청주국궁장       기타        연중무휴     5:00    22:00
# 10       배드민턴, 태권도체육관  배드민턴, 태권도체육관       기타        연중무휴     5:00    22:00
# ...

# %%
df.isna()
# Out:
#     개방시설명  개방장소명  개방시설유형구분    휴관일  평일운영시작시각  평일운영종료시각  주말운영시작시각  주말운영종료시각  \
# 0   False  False     False  False     False     False     False     False
# 1   False  False     False  False     False     False     False     False
# 2   False  False     False  False     False     False     False     False
# 3   False  False     False  False     False     False     False     False
# 4   False  False     False  False     False     False     False     False
# 5   False  False     False  False     False     False     False     False
# 6   False  False     False  False     False     False     False     False
# 7   False  False     False  False     False     False     False     False
# 8   False  False     False  False     False     False     False     False
# 9   False  False     False  False     False     False     False     False
# 10  False  False     False  False     False     False     False     False
# 11  False  False     False  False     False     False     False     False
# ...

# %%
df.columns
# Out:
# Index(['개방시설명', '개방장소명', '개방시설유형구분', '휴관일', '평일운영시작시각', '평일운영종료시각', '주말운영시작시각',
#        '주말운영종료시각', '유료사용여부', '사용기준시간', '사용료', '초과사용단위시간', '초과사용료', '수용가능인원수',
#        '면적', '부대시설정보', '신청방법구분', '시설사진정보', '소재지도로명주소', '소재지지번주소', '관리기관명',
#        '담당부서명', '사용안내전화번호', '홈페이지주소', '위도', '경도', '데이터기준일자'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=41, step=1)

# %%
df.dtypes
# Out:
# 개방시설명        object
# 개방장소명        object
# 개방시설유형구분     object
# 휴관일          object
# 평일운영시작시각     object
# 평일운영종료시각     object
# 주말운영시작시각     object
# 주말운영종료시각     object
# 유료사용여부       object
# 사용기준시간      float64
# 사용료         float64
# 초과사용단위시간    float64
# 초과사용료       float64
# 수용가능인원수     float64
# 면적          float64
# 부대시설정보       object
# 신청방법구분       object
# 시설사진정보       object
# 소재지도로명주소     object
# 소재지지번주소     float64
# 관리기관명        object
# 담당부서명        object
# 사용안내전화번호     object
# 홈페이지주소       object
# 위도          float64
# 경도          float64
# 데이터기준일자      object
# dtype: object

# %%
df.index = list('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.index = list('abc')
#
# File ~\Desktop\camp29\Pandas\venv\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\Desktop\camp29\Pandas\venv\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\Desktop\camp29\Pandas\venv\Lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# ...

# %%
df.columns
# Out:
# Index(['개방시설명', '개방장소명', '개방시설유형구분', '휴관일', '평일운영시작시각', '평일운영종료시각', '주말운영시작시각',
#        '주말운영종료시각', '유료사용여부', '사용기준시간', '사용료', '초과사용단위시간', '초과사용료', '수용가능인원수',
#        '면적', '부대시설정보', '신청방법구분', '시설사진정보', '소재지도로명주소', '소재지지번주소', '관리기관명',
#        '담당부서명', '사용안내전화번호', '홈페이지주소', '위도', '경도', '데이터기준일자'],
#       dtype='object')

# %%
df[['개방시설명', '개방장소명']]
# Out:
#                 개방시설명         개방장소명
# 0              청주유도회관        청주유도회관
# 1             충북스포츠센터       충북스포츠센터
# 2              국제테니스장        국제테니스장
# 3           청주정구장(솔밭)     청주정구장(솔밭)
# 4               실내수영장         실내수영장
# 5   올림픽기념관,     국민생활관  올림픽기념관,국민생활관
# 6           청주롤러스케이트장     청주롤러스케이트장
# 7              김수녕양궁장        김수녕양궁장
# 8              용정축구공원        용정축구공원
# 9               청주국궁장         청주국궁장
# 10       배드민턴, 태권도체육관  배드민턴, 태권도체육관
# 11         청주흥덕지구축구공원    청주흥덕지구축구공원
# 12            내수공설운동장       내수공설운동장
# 13         내수국궁장(약수정)    내수국궁장(약수정)
# 14           가덕생활체육공원      가덕생활체육공원
# 15            청주종합사격장       청주종합사격장
# 16           내수국민체육센터      내수국민체육센터
# 17             남궁유도회관        남궁유도회관
# 18            청주시립미술관       청주시립미술관
# 19              예술의전당          대전시실
# 20              예술의전당          대공연장
# 21              예술의전당          대회의실
# 22              예술의전당         소1전시실
# 23              예술의전당         소2전시실
# 24              예술의전당          소공연장
# ...
